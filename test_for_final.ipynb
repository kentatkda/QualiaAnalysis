# %%
import numpy as np
non_al_folder_path = './qualia_rawdata/non_alcohol/'
al_folder_path = './qualia_rawdata/alcohol/'
qualia_color = {
    'empatic_pain': 'orange',
    'guilt': 'black',
    'fear': 'violet',
    'anger': 'red',
    'envy': 'purple',
    'sadness': 'blue',
    'surprise': 'gray',
    'joy': 'cyan',
    'amusement': 'brown',
    'romance': 'pink',
    'aesthetic_appreciation': 'yellow',
    'awe': 'green',
}

# %% [markdown]
# ## 導通確認

# %%
from research_nonal_al import run_all
all_original_embeddings, all_embeddings, distances_df = run_all(
    non_al_folder_path=non_al_folder_path,
    al_folder_path=al_folder_path,
    iter_num=4,
    qualia_color=qualia_color
)
# Out:
# first_paths:9, second_paths: 9
# subjects:9
# all_preprocessed_dfs:(2, 9, 66, 2)
# all_dissimilarity_matrices:(2, 9, 12, 12)
# all_original_embeddings: (2, 9, 12, 2)
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:33<00:00,  8.45s/it]
# best_gw_distance: 5.222076442471427
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:02<00:00,  1.96it/s]
# best_gw_distance: 4.813505785194566
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:03<00:00,  1.26it/s]
# best_gw_distance: 5.5395442592165915
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:02<00:00,  1.71it/s]
# best_gw_distance: 2.8706950874688784
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:35<00:00,  8.83s/it]
# best_gw_distance: 4.035828705708481
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [01:22<00:00, 20.72s/it]
# best_gw_distance: 5.904932091610697
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:05<00:00,  1.29s/it]
# best_gw_distance: 3.8985873387591856
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [00:03<00:00,  1.26it/s]
# best_gw_distance: 4.165804983426182
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\MEIP-users\Desktop\codes\qualia_analysis\venv\Lib\site-packages\ot\bregman\_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# 100%|██████████| 4/4 [01:25<00:00, 21.46s/it]
# best_gw_distance: 7.647992552192214
# all_embeddings: 9
# all_distances: 9

# %% [markdown]
# ## non_alだけの導通確認

# %%
from research_nonal import run_all
